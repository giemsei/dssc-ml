# %%
bearer_token = "..." #TODO

# %%
from pprint import pprint
import tweepy
client = tweepy.Client(bearer_token)
response = client.search_recent_tweets( #TODO adjust
    query='context:26.706083889454813185',
    expansions=[
        'author_id'],
    tweet_fields=[
        'public_metrics'])
for tweet in response.data:
    pprint(tweet.data)
    print('\n')
# Out:
# {'author_id': '1221233100216205312',
#  'edit_history_tweet_ids': ['1610389084190425089'],
#  'id': '1610389084190425089',
#  'public_metrics': {'like_count': 0,
#                     'quote_count': 0,
#                     'reply_count': 0,
#                     'retweet_count': 3},
#  'text': 'RT @PompeyOnSixers: As expected, Joel Embiid is the Eastern '
#          'Conference Player of the Month for December. He becomes the first '
#          '#Sixers playe…'}
#
#
# {'author_id': '1432752982265896966',
#  'edit_history_tweet_ids': ['1610389084022743041'],
#  'id': '1610389084022743041',
#  'public_metrics': {'like_count': 0,
#                     'quote_count': 0,
#                     'reply_count': 0,
#                     'retweet_count': 16},
#  'text': 'RT @pdpatt: Just revealed 4/20 of my @savagenationnft. Don’t sleep '
#          'on this project. Art is too fire! https://t.co/GmGATFxevV'}
#
#
# {'author_id': '747425638391242752',
#  'edit_history_tweet_ids': ['1610389083838386176'],
#  'id': '1610389083838386176',
#  'public_metrics': {'like_count': 0,
#                     'quote_count': 0,
#                     'reply_count': 0,
#                     'retweet_count': 0},
#  'text': '#百家乐 #快船 #NBA https://t.co/zfYOaMtrtC\n'
#          'Citizen film fight base.\n'
#          '😀😋😆💥💋'}
#
#
# {'author_id': '805104541851152384',
#  'edit_history_tweet_ids': ['1610389083003703297'],
#  'id': '1610389083003703297',
#  'public_metrics': {'like_count': 0,
#                     'quote_count': 0,
#                     'reply_count': 0,
#                     'retweet_count': 0},
#  'text': '#中超 #NBA #CBA https://t.co/IUJrTsLhy0\n'
#          'Return bring data process effort positive.\n'
#          '💥🤏😅👌💫'}
#
#
# {'author_id': '1600584985622241280',
#  'edit_history_tweet_ids': ['1610389082802384896'],
#  'id': '1610389082802384896',
#  'public_metrics': {'like_count': 0,
#                     'quote_count': 0,
#                     'reply_count': 0,
#                     'retweet_count': 0},
#  'text': '#步行者 #NBA   \n'
#          'Different feel seven indeed never.\n'
#          '😋😀👋😆🤐 https://t.co/6v8JPrbnnw'}
#
#
# {'author_id': '491707927',
#  'edit_history_tweet_ids': ['1610389081652924416'],
#  'id': '1610389081652924416',
#  'public_metrics': {'like_count': 0,
#                     'quote_count': 0,
#                     'reply_count': 0,
#                     'retweet_count': 0},
#  'text': 'https://t.co/3OLBpYMj43 https://t.co/hB1q5anqyd'}
#
#
# {'author_id': '933928984307552257',
#  'edit_history_tweet_ids': ['1610389081518751744'],
#  'id': '1610389081518751744',
#  'public_metrics': {'like_count': 0,
#                     'quote_count': 0,
#                     'reply_count': 0,
#                     'retweet_count': 22},
#  'text': 'RT @Bam1of1: 🪜'}
#
#
# {'author_id': '4499922093',
#  'edit_history_tweet_ids': ['1610389081388879872'],
#  'id': '1610389081388879872',
#  'public_metrics': {'like_count': 0,
#                     'quote_count': 0,
#                     'reply_count': 0,
#                     'retweet_count': 0},
#  'text': 'Overshadowed by 71 from spida and the Hamlin injury '
#          'https://t.co/FiSeYN9bhF'}
#
#
# {'author_id': '3010762096',
#  'edit_history_tweet_ids': ['1610389080856055808'],
#  'id': '1610389080856055808',
#  'public_metrics': {'like_count': 0,
#                     'quote_count': 0,
#                     'reply_count': 0,
#                     'retweet_count': 8891},
#  'text': 'RT @TheHoopCentral: DONOVAN MITCHELL TONIGHT:\n'
#          '\n'
#          '71 POINTS\n'
#          '11 Assists\n'
#          '8 Rebounds\n'
#          '64% FG\n'
#          '\n'
#          'HISTORIC PERFORMANCE. 🔥🔥🔥 https://t.co/iell7nQmeS'}
#
#
# {'author_id': '1457329282074677251',
#  'edit_history_tweet_ids': ['1610389080432312326'],
#  'id': '1610389080432312326',
#  'public_metrics': {'like_count': 0,
#                     'quote_count': 0,
#                     'reply_count': 0,
#                     'retweet_count': 0},
#  'text': 'Kendrick Perkins is BUYING the Nets as true championship contenders '
#          'this season 👀 | NBA Today\n'
#          'https://t.co/VwOeZDmI4w'}

# %%
#like sempre a zero se è un retweet. Vedi:
https://twittercommunity.com/t/tweets-having-likes-more-than-zero-always-shows-zero-while-on-twitter-it-shows-more-than-zero-likes-it-only-shows-retweets-counts-accurate-please-tell-me-how-to-get-the-correct-like-count-as-well-i-am-using-twitter-v2-search-api/160840/4
